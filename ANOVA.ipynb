# %%
import pandas as pd

df1 = pd.read_excel('Statistika_SAS_ogled_JM.xls')

# %%
print(df1)
# Out:
#     Sorta-C  Faza-S   LSR     DM  DMY     CP    NPN   SolP  NPNSol     TP  \
# 0         1       1  45.0  222.2  5.1  181.8  449.3  274.9  1000.0  550.7
# 1         1       1  46.0  220.1  5.0  180.4  449.3  269.6  1000.0  550.7
# 2         1       1  44.3  221.0  5.0  177.5  449.3  271.1  1000.0  550.7
# 3         1       2  42.1  198.2  6.9  163.8  366.3  395.0   926.8  636.7
# 4         1       2  40.3  199.4  6.8  162.2  370.1  392.0   943.6  632.9
# 5         1       2  39.4  200.0  6.8  160.0  368.4  393.7   935.2  634.6
# 6         1       3  38.5  212.3  8.1  150.5  287.7  339.5   847.4  712.3
# 7         1       3  37.0  214.6  9.1  147.6  285.5  339.5   840.8  714.5
# 8         1       3  38.0  212.1  8.6  148.7  287.7  337.5   852.4  712.3
# 9         2       1  41.5  175.8  5.0  161.8  214.5  248.9   859.7  786.0
# 10        2       1  40.2  173.7  5.1  159.4  214.0  255.7   837.1  786.0
# 11        2       1  39.5  176.2  5.0  159.1  213.5  253.2   845.4  786.0
# 12        2       2  36.2  189.8  5.4  149.9  355.8  282.8  1000.0  643.2
# 13        2       2  32.7  190.2  5.6  151.9  358.4  284.1  1000.0  640.6
# 14        2       2  35.8  188.6  5.7  144.9  356.4  282.1  1000.0  642.6
# 15        2       3  31.0  196.3  8.5  134.0  269.7  270.7  1000.0  730.3
# 16        2       3  33.5  197.1  8.7  135.5  266.7  277.4   961.4  733.3
# 17        2       3  33.3  195.8  8.2  136.1  268.2  275.9   972.1  731.8
#
#     ...  NCHO  PACA  PBCB  PCCC  RDCHO  RUCHO    RDP    RUP  IDRUCHO  IDRUP
# 0   ...  43.3  78.9  38.5  28.0  661.4  338.6  760.7  239.3    213.1  161.4
# 1   ...  42.9  79.4  38.3  26.9  655.8  344.2  760.9  239.1    214.5  163.8
# 2   ...  41.9  77.1  37.3  26.6  664.9  335.1  760.9  239.1    212.8  162.4
# 3   ...  36.9  81.5  30.8  20.7  634.7  365.3  765.7  234.3    192.8  145.8
# 4   ...  36.8  77.6  30.4  17.3  633.6  366.4  768.2  231.8    194.1  148.1
# 5   ...  37.0  78.8  30.8  19.0  628.1  371.9  766.3  233.7    193.9  147.3
# 6   ...  33.3  53.9  31.1  21.4  626.7  373.3  723.6  276.4    188.2  160.2
# 7   ...  32.5  50.8  29.6  23.9  635.1  364.9  719.7  280.3    187.3  162.1
# 8   ...  32.9  52.5  30.2  22.4  631.3  368.7  722.0  278.0    187.5  161.5
# 9   ...  37.1  78.6  34.7  24.5  640.9  359.1  726.9  273.1    198.3  165.4
# 10  ...  36.5  67.7  33.6  24.9  642.0  358.0  726.4  273.6    196.5  166.8
# 11  ...  36.2  72.2  33.6  24.0  635.7  364.3  726.1  273.9    197.1  167.2
# 12  ...  33.0  53.6  29.1  26.5  660.3  339.7  712.2  287.8    193.6  178.3
# 13  ...  33.6  50.5  30.8  25.0  661.2  348.8  713.9  286.1    194.5  180.4
# 14  ...  33.5  51.4  30.0  26.3  655.6  344.4  711.7  288.3    195.2  181.2
# 15  ...  29.0  48.8  23.1  32.8  633.2  366.8  659.8  340.2    185.3  145.3
# 16  ...  29.4  47.0  24.0  32.5  636.1  363.9  652.0  348.0    186.3  147.4
# 17  ...  29.5  48.8  23.8  32.9  626.2  373.8  652.6  347.4    187.4  146.5
#
# [18 rows x 40 columns]

# %%
column_names = df1.columns.tolist()

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

for i in column_names:
    data = {
        'FactorA': df1["Faza-S"].tolist(),
        'FactorB': df1["Sorta-C"].tolist(),
        'Value': df1[i].tolist()
    }
    df = pd.DataFrame(data)
    model = ols('Value ~ C(FactorA)+C(FactorB)+C(FactorA):C(FactorB)', data=df).fit()
    anova_table = sm.stats.anova_lm(model, typ=2)
    print("**********************************************************************")
    print(i)
    print(anova_table)
# Out:
# **********************************************************************
# Sorta-C
#                              sum_sq    df             F         PR(>F)
# C(FactorA)             1.701823e-30   2.0  3.835231e+00   5.154662e-02
# C(FactorB)             4.500000e+00   1.0  2.028241e+31  9.675696e-183
# C(FactorA):C(FactorB)  3.697785e-32   2.0  8.333333e-02   9.205721e-01
# Residual               2.662406e-30  12.0           NaN            NaN
# **********************************************************************
# Faza-S
#                              sum_sq    df             F         PR(>F)
# C(FactorA)             1.200000e+01   2.0  3.894223e+30  1.337774e-179
# C(FactorB)             2.465190e-30   1.0  1.600000e+00   2.299160e-01
# C(FactorA):C(FactorB)  9.737502e-31   2.0  3.160000e-01   7.349449e-01
# Residual               1.848893e-29  12.0           NaN            NaN
# **********************************************************************
# LSR
#                            sum_sq    df          F    PR(>F)
# C(FactorA)             176.337778   2.0  53.797966  0.000001
# C(FactorB)             122.200556   1.0  74.563051  0.000002
# C(FactorA):C(FactorB)    0.751111   2.0   0.229153  0.798608
# Residual                19.666667  12.0        NaN       NaN
# **********************************************************************
# DM
#                             sum_sq    df            F        PR(>F)
# C(FactorA)              327.804444   2.0   144.477963  4.018557e-09
# C(FactorB)             2601.608889   1.0  2293.288932  4.497989e-15
# C(FactorA):C(FactorB)  1107.524444   2.0   488.135162  3.205036e-12
# Residual                 13.613333  12.0          NaN           NaN
# **********************************************************************
# DMY
#                           sum_sq    df           F        PR(>F)
# C(FactorA)             38.111111   2.0  329.807692  3.253596e-11
# C(FactorB)              0.980000   1.0   16.961538  1.424622e-03
# C(FactorA):C(FactorB)   1.453333   2.0   12.576923  1.135180e-03
# Residual                0.693333  12.0         NaN           NaN
# **********************************************************************
# CP
#                             sum_sq    df           F        PR(>F)
# C(FactorA)             2342.174444   2.0  260.692184  1.296719e-10
# C(FactorB)             1087.333889   1.0  242.048108  2.557905e-09
# C(FactorA):C(FactorB)    41.047778   2.0    4.568761  3.347828e-02
# Residual                 53.906667  12.0         NaN           NaN
# **********************************************************************
# NPN
#                              sum_sq    df             F        PR(>F)
# C(FactorA)             22202.423333   2.0   6945.492179  4.134655e-19
# C(FactorB)             35236.275556   1.0  22045.636427  5.849880e-21
# C(FactorA):C(FactorB)  48536.081111   2.0  15183.341328  3.799040e-21
# Residual                  19.180000  12.0           NaN           NaN
# **********************************************************************
# SolP
#                              sum_sq    df            F        PR(>F)
# C(FactorA)             17519.374444   2.0  1448.547267  4.926522e-15
# C(FactorB)             18818.000000   1.0  3111.841984  7.260748e-16
# C(FactorA):C(FactorB)   6252.330000   2.0   516.958842  2.280880e-12
# Residual                  72.566667  12.0          NaN           NaN
# **********************************************************************
# NPNSol
#                              sum_sq    df           F        PR(>F)
# C(FactorA)             10217.190000   2.0   48.480398  1.784292e-06
# C(FactorB)               931.680556   1.0    8.841618  1.162564e-02
# C(FactorA):C(FactorB)  66025.421111   2.0  313.289534  4.403514e-11
# Residual                1264.493333  12.0         NaN           NaN
# **********************************************************************
# TP
#                              sum_sq    df             F        PR(>F)
# C(FactorA)             21742.823333   2.0   6983.776231  4.000625e-19
# C(FactorB)             34182.408889   1.0  21958.720914  5.990117e-21
# C(FactorA):C(FactorB)  49477.147778   2.0  15892.017488  2.889680e-21
# Residual                  18.680000  12.0           NaN           NaN
# **********************************************************************
# IP
#                              sum_sq    df            F        PR(>F)
# C(FactorA)             15862.041111   2.0  1311.514653  8.920204e-15
# C(FactorB)             17672.000000   1.0  2922.333486  1.057074e-15
# C(FactorA):C(FactorB)   5462.130000   2.0   451.623059  5.079958e-12
# Residual                  72.566667  12.0          NaN           NaN
# **********************************************************************
# ADICP
#                               sum_sq    df         F    PR(>F)
# C(FactorA)              36790.167778   2.0  0.656032  0.536556
# C(FactorB)               4477.733889   1.0  0.159691  0.696462
# C(FactorA):C(FactorB)   70561.034444   2.0  1.258225  0.319099
# Residual               336478.920000  12.0       NaN       NaN
# **********************************************************************
# NDICP
#                              sum_sq    df             F        PR(>F)
# C(FactorA)             62276.907778   2.0  27327.750853  1.118696e-22
# C(FactorB)             26289.245000   1.0  23071.984885  4.452784e-21
# C(FactorA):C(FactorB)  13069.463333   2.0   5735.015602  1.303092e-18
# Residual                  13.673333  12.0           NaN           NaN
# **********************************************************************
# PA
#                              sum_sq    df            F        PR(>F)
# C(FactorA)             20688.607778   2.0  3484.234094  2.580953e-17
# C(FactorB)             12100.493889   1.0  4075.765157  1.445543e-16
# C(FactorA):C(FactorB)   2856.821111   2.0   481.126310  3.491869e-12
# Residual                  35.626667  12.0          NaN           NaN
# **********************************************************************
# PB1
#                             sum_sq    df           F        PR(>F)
# C(FactorA)              556.363333   2.0   59.006246  6.182683e-07
# C(FactorB)              722.000000   1.0  153.146359  3.428975e-08
# C(FactorA):C(FactorB)  6411.623333   2.0  679.997761  4.476837e-13
# Residual                 56.573333  12.0         NaN           NaN
# **********************************************************************
# PB2
#                               sum_sq    df             F        PR(>F)
# C(FactorA)             133638.423333   2.0  10687.273947  3.120638e-20
# C(FactorB)                851.468889   1.0    136.186600  6.594555e-08
# C(FactorA):C(FactorB)    3709.641111   2.0    296.665808  6.069142e-11
# Residual                   75.026667  12.0           NaN           NaN
# **********************************************************************
# PB3
#                              sum_sq    df            F        PR(>F)
# C(FactorA)             32216.573333   2.0  3562.466642  2.259528e-17
# C(FactorB)              4318.302222   1.0   955.024450  8.281275e-13
# C(FactorA):C(FactorB)  21867.444444   2.0  2418.073473  2.299497e-16
# Residual                  54.260000  12.0          NaN           NaN
# **********************************************************************
# PC
#                              sum_sq    df            F        PR(>F)
# C(FactorA)             16290.354444   2.0  3244.372428  3.956478e-17
# C(FactorB)              9293.388889   1.0  3701.726046  2.571240e-16
# C(FactorA):C(FactorB)   2676.481111   2.0   533.045585  1.901755e-12
# Residual                  30.126667  12.0          NaN           NaN
# **********************************************************************
# CHO
#                             sum_sq    df           F        PR(>F)
# C(FactorA)             6161.471111   2.0  441.541843  5.806382e-12
# C(FactorB)             1120.222222   1.0  160.554184  2.631514e-08
# C(FactorA):C(FactorB)   247.631111   2.0   17.745680  2.602554e-04
# Residual                 83.726667  12.0         NaN           NaN
# **********************************************************************
# TESC
#                             sum_sq    df           F        PR(>F)
# C(FactorA)             6054.603333   2.0  234.291126  2.423713e-10
# C(FactorB)              251.627222   1.0   19.474116  8.459723e-04
# C(FactorA):C(FactorB)   982.341111   2.0   38.013028  6.418300e-06
# Residual                155.053333  12.0         NaN           NaN
# **********************************************************************
# NFC
#                             sum_sq    df          F    PR(>F)
# C(FactorA)             4771.007778   2.0  46.134830  0.000002
# C(FactorB)             2106.005000   1.0  40.729417  0.000035
# C(FactorA):C(FactorB)   464.923333   2.0   4.495729  0.034901
# Residual                620.486667  12.0        NaN       NaN
# **********************************************************************
# NDF
#                             sum_sq    df          F    PR(>F)
# C(FactorA)             1552.964444   2.0  34.239784  0.000011
# C(FactorB)               35.000556   1.0   1.543386  0.237845
# C(FactorA):C(FactorB)    77.817778   2.0   1.715728  0.221129
# Residual                272.133333  12.0        NaN       NaN
# **********************************************************************
# ADF
#                             sum_sq    df           F        PR(>F)
# C(FactorA)             5024.441111   2.0  166.048434  1.798884e-09
# C(FactorB)             1145.608889   1.0   75.720486  1.573746e-06
# C(FactorA):C(FactorB)  1253.007778   2.0   41.409577  4.108763e-06
# Residual                181.553333  12.0         NaN           NaN
# **********************************************************************
# HCL
#                             sum_sq    df          F    PR(>F)
# C(FactorA)             1089.614444   2.0  13.295187  0.000904
# C(FactorB)              778.808889   1.0  19.005640  0.000929
# C(FactorA):C(FactorB)   989.807778   2.0  12.077373  0.001337
# Residual                491.733333  12.0        NaN       NaN
# **********************************************************************
# ADL
#                            sum_sq    df          F    PR(>F)
# C(FactorA)             556.321111   2.0  51.809706  0.000001
# C(FactorB)              26.160556   1.0   4.872620  0.047502
# C(FactorA):C(FactorB)  308.287778   2.0  28.710575  0.000027
# Residual                64.426667  12.0        NaN       NaN
# **********************************************************************
# CA
#                             sum_sq    df           F        PR(>F)
# C(FactorA)             8785.074444   2.0  164.336694  1.910109e-09
# C(FactorB)              900.293889   1.0   33.682429  8.425052e-05
# C(FactorA):C(FactorB)  2233.474444   2.0   41.780159  3.921227e-06
# Residual                320.746667  12.0         NaN           NaN
# **********************************************************************
# CB1
#                            sum_sq    df         F    PR(>F)
# C(FactorA)             239.790000   2.0  3.714603  0.055508
# C(FactorB)              63.093889   1.0  1.954783  0.187379
# C(FactorA):C(FactorB)   28.941111   2.0  0.448329  0.648970
# Residual               387.320000  12.0       NaN       NaN
# **********************************************************************
# CB2
#                             sum_sq    df          F    PR(>F)
# C(FactorA)              793.737778   2.0   5.757564  0.017661
# C(FactorB)             4672.222222   1.0  67.782130  0.000003
# C(FactorA):C(FactorB)  1656.031111   2.0  12.012412  0.001366
# Residual                827.160000  12.0        NaN       NaN
# **********************************************************************
# CB3
#                              sum_sq    df          F        PR(>F)
# C(FactorA)             12236.653333   2.0  83.837577  8.874815e-08
# C(FactorB)              3141.602222   1.0  43.048424  2.685455e-05
# C(FactorA):C(FactorB)   3518.324444   2.0  24.105267  6.266897e-05
# Residual                 875.740000  12.0        NaN           NaN
# **********************************************************************
# CC
#                             sum_sq    df          F    PR(>F)
# C(FactorA)             3967.030000   2.0  48.442742  0.000002
# C(FactorB)              121.680000   1.0   2.971751  0.110371
# C(FactorA):C(FactorB)  3275.903333   2.0  40.003161  0.000005
# Residual                491.346667  12.0        NaN       NaN
# **********************************************************************
# NCHO
#                            sum_sq    df           F        PR(>F)
# C(FactorA)             219.541111   2.0  613.624224  8.243985e-13
# C(FactorB)              87.560556   1.0  489.468944  4.279933e-11
# C(FactorA):C(FactorB)    6.421111   2.0   17.947205  2.473879e-04
# Residual                 2.146667  12.0         NaN           NaN
# **********************************************************************
# PACA
#                             sum_sq    df           F        PR(>F)
# C(FactorA)             1954.734444   2.0  141.340162  4.560166e-09
# C(FactorB)              695.645000   1.0  100.599422  3.467508e-07
# C(FactorA):C(FactorB)   510.043333   2.0   36.879489  7.506023e-06
# Residual                 82.980000  12.0         NaN           NaN
# **********************************************************************
# PBCB
#                            sum_sq    df           F        PR(>F)
# C(FactorA)             250.247778   2.0  314.557263  4.300053e-11
# C(FactorB)              65.360556   1.0  164.314246  2.310683e-08
# C(FactorA):C(FactorB)   26.847778   2.0   33.747207  1.183226e-05
# Residual                 4.773333  12.0         NaN           NaN
# **********************************************************************
# PCCC
#                            sum_sq    df           F        PR(>F)
# C(FactorA)              82.901111   2.0   41.963442  3.832176e-06
# C(FactorB)             103.680000   1.0  104.962880  2.755057e-07
# C(FactorA):C(FactorB)  134.403333   2.0   68.033183  2.833668e-07
# Residual                11.853333  12.0         NaN           NaN
# **********************************************************************
# RDCHO
#                             sum_sq    df          F    PR(>F)
# C(FactorA)             1139.681111   2.0  35.053928  0.000010
# C(FactorB)               21.342222   1.0   1.312874  0.274211
# C(FactorA):C(FactorB)  1737.074444   2.0  53.428352  0.000001
# Residual                195.073333  12.0        NaN       NaN
# **********************************************************************
# RUCHO
#                             sum_sq    df          F    PR(>F)
# C(FactorA)             1086.681111   2.0  29.852965  0.000022
# C(FactorB)                5.120000   1.0   0.281310  0.605520
# C(FactorA):C(FactorB)  1500.963333   2.0  41.233998  0.000004
# Residual                218.406667  12.0        NaN       NaN
# **********************************************************************
# RDP
#                              sum_sq    df            F        PR(>F)
# C(FactorA)             11443.163333   2.0  1325.804197  8.361135e-15
# C(FactorB)             12084.942222   1.0  2800.321318  1.363972e-15
# C(FactorA):C(FactorB)    809.087778   2.0    93.740860  4.738805e-08
# Residual                  51.786667  12.0          NaN           NaN
# **********************************************************************
# RUP
#                              sum_sq    df            F        PR(>F)
# C(FactorA)             11443.163333   2.0  1325.804197  8.361135e-15
# C(FactorB)             12084.942222   1.0  2800.321318  1.363972e-15
# C(FactorA):C(FactorB)    809.087778   2.0    93.740860  4.738805e-08
# Residual                  51.786667  12.0          NaN           NaN
# **********************************************************************
# IDRUCHO
#                             sum_sq    df           F        PR(>F)
# C(FactorA)             1032.763333   2.0  751.404204  2.471390e-13
# C(FactorB)              138.888889   1.0  202.101859  7.167643e-09
# C(FactorA):C(FactorB)   256.861111   2.0  186.883589  9.060159e-10
# Residual                  8.246667  12.0         NaN           NaN
# **********************************************************************
# IDRUP
#                             sum_sq    df           F        PR(>F)
# C(FactorA)              417.023333   2.0  156.253539  2.557069e-09
# C(FactorB)              241.267222   1.0  180.799750  1.347958e-08
# C(FactorA):C(FactorB)  1737.081111   2.0  650.863031  5.808428e-13
# Residual                 16.013333  12.0         NaN           NaN
